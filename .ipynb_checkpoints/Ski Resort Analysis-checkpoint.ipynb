# %% [markdown]
# # Ski Resort Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pymysql

# %%
rds_connection_string = "root:<password>@localhost:3306/ski_resorts_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
# check for tables
engine.table_names()
# Out:
# ['clean_skiresortnortamerica', 'skiresort']

# %%
# setting variable to reference the csv file
skiResorts = "Resources/clean_skiResortNortAmerica.csv"
# bringing the csv into a pandas dataframe
resorts_df = pd.read_csv(skiResorts)
# convert null / NaN values
resorts_df.fillna("empty", inplace=True)
# printing first five records in the dataframe
resorts_df.head()
# Out:
#    ID                        ResortName      Continent Country  \
# 0   2  49-degrees-north-mountain-resort  North America     USA
# 1  14                           abenaki  North America     USA
# 2  15       aberdeen-heli-prince-george  North America  Canada
# 3  24                          adamants  North America  Canada
# 4  25                   adanac-ski-hill  North America  Canada
#
#       StateProvince                                                URL  \
# 0  Washington State  http://www.skiresort.info/ski-resort/49-degree...
# 1     New Hampshire      http://www.skiresort.info/ski-resort/abenaki/
# 2  British Columbia  http://www.skiresort.info/ski-resort/aberdeen-...
# 3  British Columbia     http://www.skiresort.info/ski-resort/adamants/
# 4           Ontario  http://www.skiresort.info/ski-resort/adanac-sk...
#
#    Altitude   Easy Intermediate Difficult     ...     Cross-countryTrails  \
# 0      1760     20           27        21     ...                   empty
# 1       250    0.5          0.3       0.2     ...                   empty
# 2         0  empty        empty     empty     ...                   empty
# 3      3100  empty        empty     empty     ...                   empty
# 4       340    1.3          0.6       0.1     ...                   empty
#
#   AerialTramwayReverseRopeway RopeTowBeginnerLift PeopleMover  \
# 0                       empty                   0       empty
# 1                       empty               empty       empty
# 2                       empty               empty       empty
# 3                       empty               empty       empty
# 4                       empty               empty           0
#
#   CombinedGondolaChair  CogRailway  Helicopter  SnowCaterpillars   Latitude  \
# 0                empty       empty       empty             empty  48.301097
# 1                empty       empty       empty             empty  43.611548
# 2                empty       empty           0             empty  53.882664
# 3                empty       empty           0             empty  51.632117
# 4                empty       empty       empty             empty  46.510561
#
#     Longitude
# 0 -117.562916
# 1  -71.229107
# 2 -122.676198
# 3 -118.169138
# 4  -80.960432
#
# [5 rows x 46 columns]
